# %%
import numpy as np
import matplotlib.pyplot as plt
plt.plot(np.arange(10))

# %%
# Figure ，axes对象 

import matplotlib.pyplot as plt
import numpy as np
 
fig=plt.figure()

add_subplot1=fig.add_subplot(2,2,1)
# 利用axessubplot对象绘制
add_subplot1.hist(np.random.randn(10),bins=20,color='k',alpha=0.3)

# 绘制点
add_subplot2=fig.add_subplot(2,2,2)
add_subplot2.scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))

# 绘制虚线
add_subplot3=fig.add_subplot(2,2,3)
a=np.array([0,1,3,1,4,5])
plt.plot(a,'k--',color='#23CEF2')
plt.plot(a.cumsum(),'k-')

# 设置刻度范围
add_subplot3.xlim(0,10)

# 设置刻度的标签
add_subplot3.set_xlabel('sss')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-df9f95ce19b2> in <module>()
#      21
#      22 # 设置刻度
# ---> 23 add_subplot3.slim(0,10)
#      24 add_subplot3.set_xlabel('sss')
#      25 # 设置刻度的标签
#
# AttributeError: 'AxesSubplot' object has no attribute 'slim'
