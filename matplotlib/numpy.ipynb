# %%
import numpy as np
import matplotlib.pyplot as plt

ps=np.arange(-1,1,0.1)
x,y=np.meshgrid(ps,ps)
z=np.sqrt(x**2+y**2)

plt.imshow(z,cmap=plt.cm.gray);
plt.colorbar()
plt.title("image $\sqrt{x^2+y^2}$")
# Out:
# Text(0.5,1,'image $\\sqrt{x^2+y^2}$')
